# %% [markdown]
# # 02 — PC: portfolio choice
#
# Stub notebook. Populated during **Controversy 6**.
#
# Goal: reproduce the PC (portfolio-choice) model from Godley & Lavoie, in which households allocate wealth between cash and government bills based on a Tobin-style portfolio rule.
#
# **Reference:** Godley & Lavoie, *Monetary Economics*, Chapter 4.

# %%
# from sfc_models.gl_book.chapter4 import PC
# ... TODO
