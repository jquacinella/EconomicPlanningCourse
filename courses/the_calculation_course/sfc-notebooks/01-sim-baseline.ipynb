# %% [markdown]
# # 01 — SIM baseline
#
# Stub notebook. Populated during **Controversy 6, Version 1**.
#
# Goal: reproduce the SIM model (the simplest Godley–Lavoie stock-flow consistent model: a closed economy with a government and households, no banks, no firms beyond a passive production sector) using `sfc_models.gl_book.SIM`. Simulate, plot the steady-state convergence, and verify against the textbook's eViews reference values.
#
# **Reference:** Godley & Lavoie, *Monetary Economics* (2nd ed., 2012), Chapter 3.

# %%
# import sfc_models
# from sfc_models.gl_book.chapter3 import SIM
# ... TODO
