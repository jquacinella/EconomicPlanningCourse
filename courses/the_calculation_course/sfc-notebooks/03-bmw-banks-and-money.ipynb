# %% [markdown]
# # 03 — BMW: banks and money
#
# Stub notebook. Populated during **Controversy 6, Version 2** (endogenous bank credit).
#
# Goal: reproduce the BMW (banks-and-money) model from Godley & Lavoie. This is the backbone for Version 2 of the Controversy 6 capstone, where endogenous bank credit creation is introduced on top of the SIM baseline.
#
# **Reference:** Godley & Lavoie, *Monetary Economics*, Chapter 7.

# %%
# from sfc_models.gl_book.chapter7 import BMW
# ... TODO
